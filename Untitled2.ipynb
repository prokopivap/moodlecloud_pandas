# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('AirBnB_NY/AB_NYC_2019.csv')
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# Calculate mean of availability_365 for each room_type across neighbourhood_group
grouped_df = df.groupby(['neighbourhood_group', 'room_type']).agg(mean_availability=('availability_365', 'mean')
).reset_index()

print(grouped_df)
# Out:
#    neighbourhood_group        room_type  mean_availability
# 0                Bronx  Entire home/apt         158.000000
# 1                Bronx     Private room         171.331288
# 2                Bronx      Shared room         154.216667
# 3             Brooklyn  Entire home/apt          97.205147
# 4             Brooklyn     Private room          99.917983
# 5             Brooklyn      Shared room         178.007264
# 6            Manhattan  Entire home/apt         117.140996
# 7            Manhattan     Private room         101.845026
# 8            Manhattan      Shared room         138.572917
# 9               Queens  Entire home/apt         132.267176
# 10              Queens     Private room         149.222716
# 11              Queens      Shared room         192.186869
# 12       Staten Island  Entire home/apt         178.073864
# 13       Staten Island     Private room         226.361702
# 14       Staten Island      Shared room          64.777778

# %%
# Set up the figure and axes
plt.figure(figsize=(14, 8))

# Get unique values for neighborhoods and room types
neighbourhoods = grouped_df['neighbourhood_group'].unique()
room_types = grouped_df['room_type'].unique()

# Define bar width and positions
bar_width = 0.2
index = np.arange(len(neighbourhoods))  #[0 1 2 3 4] identify how many blocks of bars will be present, how many neighbourgroups

# Create bars for each room type
for i, room_type in enumerate(room_types): #0 Entire home/apt, 1 Private room, 2 Shared room
    subset = grouped_df[grouped_df['room_type'] == room_type]
    plt.bar(index + i * bar_width,         # x
            subset['mean_availability'],   # y
            width=bar_width,
            label=room_type,
            capsize=5)  # Adds caps to the error bars

# Add titles and labels
plt.title('Average Availability by Room Type Across Neighbourhoods')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Average Availability (days)')
plt.xticks(index + bar_width, neighbourhoods)  # Add lables to the x axis (neighbourhoods)
plt.legend(title='Room Type')

plt.show()

# %%
# Define colors and markers for each room type
colors = {'Entire home/apt': 'skyblue', 'Private room': 'lightgreen', 'Shared room': 'lightcoral'}
markers = {'Entire home/apt': 'o', 'Private room': 's', 'Shared room': 'D'}

# %%
plt.figure(figsize=(10, 6))

room_types = df['room_type'].unique()

# Plot each room_type with a different color and marker
for room_type in room_types:
    subset = df[df['room_type'] == room_type]
    plt.scatter(subset['price'],             # x         
                subset['number_of_reviews'], # y
                color=colors[room_type], 
                marker=markers[room_type], 
                #label=room_type, 
                s=20)

    # Add a regression line for each room type
    slope, intercept = np.polyfit(subset['price'], subset['number_of_reviews'], 1)
    plt.plot(subset['price'], slope * subset['price'] + intercept, color=colors[room_type], linestyle='--')

# Add titles and labels
plt.title('Price vs. Number of Reviews by Room Type')
plt.xlabel('Price')
plt.ylabel('Number of Reviews')

# Add a legend
plt.legend(title='Room Type')

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# - Plot: Create a line plot to show the trend of number_of_reviews over time
# (last_review) for each neighbourhood_group.
# - Details: Use different colors for each neighborhood group, smooth the data with a
# rolling average, and add titles, axis labels, and a legend.



# Convert last_review to a datetime object
df['last_review'] = pd.to_datetime(df['last_review'])

# Set a rolling window size, e.g., 2 periods
rolling_window_size = 3

# Apply rolling average for each neighbourhood_group
df['rolling_avg_reviews'] = df.groupby('neighbourhood_group')['number_of_reviews'].transform(lambda x: x.rolling(window=rolling_window_size).mean())
plt.figure(figsize=(12, 8))

# Define colors for each neighborhood group
colors = {'Manhattan': 'blue', 'Brooklyn': 'green', 'Queens': 'red', 'Bronx': 'orange', 'Staten Island': 'yellow'}

# Plot each neighbourhood_group with a different color
for neighbourhood in df['neighbourhood_group'].unique():
    subset = df[df['neighbourhood_group'] == neighbourhood]
    plt.plot(subset['last_review'], subset['rolling_avg_reviews'], 
             color=colors[neighbourhood], 
             label=neighbourhood, 
             marker='o')

# Add titles and labels
plt.title('Trend of Number of Reviews Over Time by Neighbourhood Group')
plt.xlabel('Date of Last Review')
plt.ylabel('Rolling Average of Number of Reviews')

# Add a legend
plt.legend(title='Neighbourhood Group')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Calculate the mean price and availability_365 for each neighbourhood_group
heatmap_data = df.groupby('neighbourhood_group').agg({
    'price': 'mean',
    'availability_365': 'mean'
}).reset_index()

heatmap_data['price'] = heatmap_data['price'].round(2)

# Pivot the data to create a matrix for the heatmap
heatmap_data_pivot = heatmap_data.pivot(index = 'neighbourhood_group', columns = 'price', values = 'availability_365')

# Create the heatmap using matplotlib
plt.figure(figsize=(10, 8))

# Use the pcolormesh function to create the heatmap
plt.pcolormesh(heatmap_data_pivot, cmap='YlGnBu', edgecolors='black', shading='auto')

# Add color bar for reference
plt.colorbar(label='Average Availability (days)')

# Label the axes
plt.title('Heatmap of Price vs Availability Across Neighbourhoods')
plt.xlabel('Average Price')
plt.ylabel('Neighbourhood Group')

# Adjust the ticks for x and y axis
plt.xticks(np.arange(0.5, len(heatmap_data_pivot.columns), 1), heatmap_data_pivot.columns) #allign on center lables axis x
plt.yticks(np.arange(0.5, len(heatmap_data_pivot.index), 1), heatmap_data_pivot.index)  # allign on center lables axis y

plt.show()

# %%
# - Plot: Create a stacked bar plot to display the number_of_reviews for each
# room_type across the neighbourhood_group.
# - Details: Stack the bars by room type, use different colors for each room type, and
# add titles, axis labels, and a legend.

pivot_df = df.pivot_table(index='neighbourhood_group', columns='room_type', values='number_of_reviews', aggfunc='sum', fill_value=0)

print(pivot_df)


# Set up the plot
plt.figure(figsize=(10, 8))

# Define colors for each room type
colors = ['skyblue', 'lightgreen', 'lightcoral']

# Plot the stacked bar chart
pivot_df.plot(kind='bar', stacked=True, color=colors, edgecolor='black')

# Add titles and labels
plt.title('Number of Reviews by Room Type Across Neighbourhoods')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Number of Reviews')

# Add a legend
plt.legend(title='Room Type')

# Show the plot
plt.show()
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                          11627         16312          432
# Brooklyn                      267128        213653         5793
# Manhattan                     235147        209150        10272
# Queens                         60644         93561         2745
# Staten Island                   5857          5670           14

# %%
import pandas as pd

# Load the Titanic dataset
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# Handle missing values in Age by filling with the median
df['Age'].fillna(df['Age'].median(), inplace=True)

# Create the AgeGroup column using np.where
df['AgeGroup'] = np.where(df['Age'] < 13, 'Child',
                          np.where(df['Age'] < 25, 'Young Adult',
                                   np.where(df['Age'] < 60, 'Adult', 'Senior')))

# Group by Pclass, Sex, AgeGroup
grouped_df = df.groupby(['Pclass', 'Sex', 'AgeGroup'])['Survived'].mean().reset_index()
#display(grouped_df)

# Convert the survival rate to percentage
grouped_df['SurvivalRate'] = grouped_df['Survived'] * 100

# Merge the SurvivalRate back to the original dataframe
df = pd.merge(df, grouped_df[['Pclass', 'Sex', 'AgeGroup', 'SurvivalRate']],
              on=['Pclass', 'Sex', 'AgeGroup'], how='left')

display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pip install bokeh
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.transform import factor_cmap
from bokeh.palettes import Spectral6

# Output the plot to the notebook (if you're using a Jupyter Notebook)
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c27bb409-5477-42a5-87a2-d9b9afe54831">Loading BokehJS ...</span>
#     </div>

# %%
# Load the Titanic dataset
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# Handle missing values in Age by filling with the median
df['Age'].fillna(df['Age'].median(), inplace=True)

# Create the AgeGroup column by categorizing ages into bins
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 12, 24, 59, 120], labels=['Child', 'Young Adult', 'Adult', 'Senior'])

# Calculate survival rates for each AgeGroup
age_group_survival = df.groupby('AgeGroup')['Survived'].mean() * 100  # Convert to percentage
age_group_survival = age_group_survival.reset_index()
age_group_survival.columns = ['AgeGroup', 'SurvivalRate']

# Convert the data to a ColumnDataSource for Bokeh
source = ColumnDataSource(age_group_survival)

# %%
# Define a color map for the age groups
age_groups = age_group_survival['AgeGroup'].tolist()
colors = factor_cmap('AgeGroup', palette=Spectral6, factors=age_groups)

# Create the figure
p = figure(x_range=age_groups,  title="Survival Rates by Age Group",
           toolbar_location=None, tools="")

# Add bars to the plot
p.vbar(x='AgeGroup', top='SurvivalRate', width=0.9, source=source, line_color='white', fill_color=colors)

# Customize the plot
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.yaxis.axis_label = "Survival Rate (%)"
p.xaxis.axis_label = "Age Group"

# Add a hover tool
p.add_tools(HoverTool(tooltips=[("Age Group", "@AgeGroup"), ("Survival Rate", "@SurvivalRate{0.2f}%")]))

# Show the plot
show(p)
# Out:
#   <div id="a34cb5ac-c0c0-40ef-87a5-d76910294cb7" data-root-id="p1120" style="display: contents;"></div>

# %%
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource

# Output the plot to the notebook (useful for Jupyter Notebooks)
output_notebook()

# Load the Titanic dataset
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# Handle missing values in Age by filling with the median
df['Age'].fillna(df['Age'].median(), inplace=True)

# Create the AgeGroup column by categorizing ages into bins
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 12, 24, 59, 120], labels=['Child', 'Young Adult', 'Adult', 'Senior'])

# Calculate survival rates for each AgeGroup
age_group_survival = df.groupby('AgeGroup')['Survived'].mean() * 100  # Convert to percentage
age_group_survival = age_group_survival.reset_index()

# Convert the categorical AgeGroup to a string list for Bokeh
age_group_survival['AgeGroup'] = age_group_survival['AgeGroup'].astype(str)

#display(age_group_survival)


# Convert the data to a ColumnDataSource for Bokeh
source = ColumnDataSource(age_group_survival)

# Create the figure with string categories for x_range
p = figure(x_range=age_group_survival['AgeGroup'].tolist(), title="Survival Rates by Age Group",
           toolbar_location=None, tools="")

# Add bars to the plot
p.vbar(x='AgeGroup', top='Survived', width=0.9, source=source, color='skyblue')

# Customize the plot
p.y_range.start = 0
p.yaxis.axis_label = "Survival Rate (%)"
p.xaxis.axis_label = "Age Group"

# Show the plot
show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a919f533-ddc4-490c-9239-97c8e818250b">Loading BokehJS ...</span>
#     </div>
#   <div id="ebd45dbf-9f88-4069-8b14-9ff87c867b91" data-root-id="p1158" style="display: contents;"></div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('AirBnB_NY/AB_NYC_2019.csv')

# %%
# Convert 'last_review' to datetime format
df['last_review'] = pd.to_datetime(df['last_review'])

df = df[df['last_review'] >= '2018-11-01']

# Drop rows with missing last_review values
df = df.dropna(subset=['last_review'])

# %%
# Group by neighbourhood_group and last_review to calculate the number of reviews per group over time
grouped_df = df.groupby(['neighbourhood_group', 'last_review']).agg({'number_of_reviews': 'sum'}).reset_index()

# Apply rolling average with a window of 6 months for smoothing
grouped_df['rolling_avg_reviews'] = grouped_df.groupby('neighbourhood_group')['number_of_reviews'].transform(lambda x: x.rolling(window=6, min_periods=1).mean())

# %%
plt.figure(figsize=(14, 8))

# Get unique neighbourhood groups
neighbourhoods = grouped_df['neighbourhood_group'].unique()

# Define colors manually if you want or let matplotlib choose automatically
colors = plt.cm.get_cmap('tab10', len(neighbourhoods))

# Plot each neighbourhood_group with a different color
for i, neighbourhood in enumerate(neighbourhoods):
    subset = grouped_df[grouped_df['neighbourhood_group'] == neighbourhood]
    plt.plot(subset['last_review'], subset['rolling_avg_reviews'], label=neighbourhood, color=colors(i))

# Add titles and labels
plt.title('Trend of Number of Reviews Over Time by Neighbourhood Group', fontsize=16)
plt.xlabel('Last Review Date', fontsize=14)
plt.ylabel('Rolling Average of Number of Reviews', fontsize=14)

# Add a legend
plt.legend(title='Neighbourhood Group')

# Display the plot
plt.show()
# Out:
# /var/folders/hl/0yvjm13s1hzc40r3hv5cw51r0000gn/T/ipykernel_4119/2394093923.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(neighbourhoods))

# %%
df['last_review'] = pd.to_datetime(df['last_review'])

# Drop rows with missing last_review values
df = df.dropna(subset=['last_review'])

# %%
# Group by neighbourhood_group and last_review, then sum the number of reviews
grouped_df = df.groupby(['neighbourhood_group', 'last_review']).agg({'number_of_reviews': 'sum'}).reset_index()

# Apply a rolling average with a window of 6 to smooth the data
grouped_df['rolling_avg_reviews'] = grouped_df.groupby('neighbourhood_group')['number_of_reviews'].rolling(window=6, min_periods=1).mean().reset_index(level=0, drop=True)

# %%
# Set up the plot
plt.figure(figsize=(14, 8))

# Plot each neighbourhood_group
for neighbourhood in grouped_df['neighbourhood_group'].unique():
    subset = grouped_df[grouped_df['neighbourhood_group'] == neighbourhood]
    plt.plot(subset['last_review'], subset['rolling_avg_reviews'], label=neighbourhood)

# Add titles and labels
plt.title('Trend of Number of Reviews Over Time by Neighbourhood Group')
plt.xlabel('Last Review Date')
plt.ylabel('Rolling Average of Number of Reviews')

# Add a legend
plt.legend(title='Neighbourhood Group')

# Display the plot
plt.show()

# %%
# Set up the figure size
plt.figure(figsize=(10, 15))

# Generate the box plot
box = plt.boxplot([df[df['neighbourhood_group'] == group]['price'] for group in df['neighbourhood_group'].unique()],
                  patch_artist=True,  # Fill the boxes with color
                  labels=df['neighbourhood_group'].unique(),  # Label the x-axis with neighborhood groups
                  showfliers=True)  # Show outliers

# Add colors to each box
colors = ['lightblue', 'lightgreen', 'lightcoral', 'lightsalmon', 'lightpink']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Add titles and labels
plt.title('Price Distribution by Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Price')

# Show the plot
plt.show()

# %%
import pandas as pd
from bokeh.plotting import figure, show, output_file
from bokeh.transform import factor_cmap
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.io import output_notebook

output_notebook()

df = pd.read_csv('/Users/aprokopiv/moodlecloud/moodlecloud_visualization/Titanic/Titanic-Dataset.csv')
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f4a312e3-6267-4003-adad-5af5cc650646">Loading BokehJS ...</span>
#     </div>

# %%
# Calculate survival rates
survival_rates = df.groupby(['Pclass', 'Sex'])['Survived'].mean().unstack()

# Convert the DataFrame to a format that Bokeh can use (ColumnDataSource)
survival_rates = survival_rates.reset_index()
survival_rates = pd.melt(survival_rates, id_vars=['Pclass'], value_vars=['male', 'female'], var_name='Sex', value_name='Survival_Rate')

# %%
# Prepare data for Bokeh
survival_rates['Pclass_Sex'] = list(zip(survival_rates['Pclass'].astype(str), survival_rates['Sex']))
source = ColumnDataSource(survival_rates)

# Define the factors for x-axis
factors = [(str(cls), gender) for cls in [1, 2, 3] for gender in ['male', 'female']]

# %%
# Create a figure
p = figure(x_range=FactorRange(*factors), height=400, width=700, title="Survival Rates by Class and Gender",
           toolbar_location=None, tools="")

# Add bars
p.vbar(x='Pclass_Sex', top='Survival_Rate', width=0.8, source=source,
       fill_color=factor_cmap('Pclass_Sex', palette=['lightblue', 'lightgreen'], factors=['male', 'female'], start=1, end=2))

# Customize the plot
p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.yaxis.axis_label = 'Survival Rate'
p.xaxis.axis_label = 'Class and Gender'
p.xaxis.major_label_orientation = 1

# Show the plot
show(p)
# Out:
#   <div id="a888f43a-167a-4054-afa1-19ecc96d8b40" data-root-id="p1196" style="display: contents;"></div>

# %%
df_fare_survival = df_grouped.copy()

df_fare_survival['Pclass'] = df_fare_survival['Pclass'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df_fare_survival = df_grouped.copy()
#       3 df_fare_survival['Pclass'] = df_fare_survival['Pclass'].astype(str)
#
# NameError: name 'df_grouped' is not defined

# %%
# Create a ColumnDataSource
source = ColumnDataSource(df_fare_survival)

# Create a color mapping for the different classes
color_map = factor_cmap('Pclass', palette=['blue', 'green', 'red'], factors=['1', '2', '3'])

# Create the figure
p = figure(width=800, height=400, title="Scatter Plot of Fare vs Survival Status by Class",
           x_axis_label="Fare", y_axis_label="Survived", tools="pan,box_zoom,reset,save")

# Add the scatter plot
p.circle(x='Fare', y='Survived', size=10, color=color_map, legend_field='Pclass', source=source, fill_alpha=0.4)

# Customize the legend
p.legend.title = 'Class'
p.legend.location = 'top_right'

# Show the plot
show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Create a ColumnDataSource
# ----> 2 source = ColumnDataSource(df_fare_survival)
#       4 # Create a color mapping for the different classes
#       5 color_map = factor_cmap('Pclass', palette=['blue', 'green', 'red'], factors=['1', '2', '3'])
#
# NameError: name 'df_fare_survival' is not defined
